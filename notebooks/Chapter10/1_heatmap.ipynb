# %%
# %load_ext autoreload
# %autoreload 2
from naml.modules import torch
from naml.plot import heatmap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
t = torch.rand((10,10))
heatmap(t, label_x='x', label_y='y', title='Random Heatmap')
