# %%
# %load_ext autoreload
# %autoreload 2

from naml import plot
from time import sleep

def gen():
    for i in range(0,11):
        sleep(0.1)
        yield (i,i+1,i+2)

plot.simple_animated(gen(), 3, 10, labels_y=['a','b','c'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
